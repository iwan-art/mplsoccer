# %%
from mplsoccer.pitch import Pitch

# %%
pitch = Pitch(pitch_type = "statsbomb")

# %%
pitch.draw()
# Out:
# (<Figure size 460.8x345.6 with 1 Axes>, <AxesSubplot:>)

# %%
pitch = Pitch(pitch_color = "grass",
              line_color = "white",
              stripe = True)
fig, ax = pitch.draw()

# %%
pitch = Pitch(pitch_type='statsbomb',
              pitch_color='#22312b',
              line_color='#c7d5cc')
fig, ax = pitch.draw(figsize=(8, 8),
                     constrained_layout=True,
                     tight_layout=False)
fig.set_facecolor('#22312b')
